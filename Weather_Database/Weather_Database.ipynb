# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests as req

# Import the API key.
from config import weather_api_key

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs=np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 746

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description=city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | airai
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | balutakay
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | amahai
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | luderitz
# Processing Record 11 of Set 1 | feijo
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | olga
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | zunyi
# Processing Record 16 of Set 1 | iztapa
# Processing Record 17 of Set 1 | lokomotivnyy
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | sioux lookout
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | nam tha
# City not found. Skipping...
# Processing Record 22 of Set 1 | xghajra
# City not found. Skipping...
# Processing Record 23 of Set 1 | vila velha
# Processing Record 24 of Set 1 | moose factory
# Processing Record 25 of Set 1 | mahajanga
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | kavieng
# Processing Record 28 of Set 1 | porbandar
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | parry sound
# Processing Record 31 of Set 1 | ahipara
# Processing Record 32 of Set 1 | dudinka
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | boysun
# Processing Record 35 of Set 1 | sitka
# Processing Record 36 of Set 1 | aklavik
# Processing Record 37 of Set 1 | kracheh
# City not found. Skipping...
# Processing Record 38 of Set 1 | nanortalik
# Processing Record 39 of Set 1 | san patricio
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | salvador
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | springdale
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | kaolinovo
# Processing Record 47 of Set 1 | bilma
# Processing Record 48 of Set 1 | litoral del san juan
# City not found. Skipping...
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | mardin
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | iquique
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | jiutai
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | bilibino
# Processing Record 10 of Set 2 | nushki
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | pangnirtung
# Processing Record 15 of Set 2 | esmeraldas
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | slave lake
# Processing Record 19 of Set 2 | gazimurskiy zavod
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | mandera
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | santa cruz
# Processing Record 24 of Set 2 | salyan
# Processing Record 25 of Set 2 | pasighat
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | vanimo
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | beringovskiy
# Processing Record 31 of Set 2 | birao
# Processing Record 32 of Set 2 | constitucion
# Processing Record 33 of Set 2 | kahului
# Processing Record 34 of Set 2 | kautokeino
# Processing Record 35 of Set 2 | progreso
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | lata
# Processing Record 39 of Set 2 | wagar
# Processing Record 40 of Set 2 | ushuaia
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | kumluca
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | kavaratti
# Processing Record 46 of Set 2 | narsaq
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | anadyr
# Processing Record 2 of Set 3 | poya
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 3 | severnyy
# Processing Record 10 of Set 3 | itoman
# Processing Record 11 of Set 3 | presidente dutra
# Processing Record 12 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 3 | cururupu
# Processing Record 14 of Set 3 | sao joao da barra
# Processing Record 15 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 3 | carauari
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | saint-augustin
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | kapaa
# Processing Record 21 of Set 3 | saint anthony
# Processing Record 22 of Set 3 | egvekinot
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | padang
# Processing Record 25 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 3 | simpang empat
# Processing Record 27 of Set 3 | mnogovershinnyy
# Processing Record 28 of Set 3 | meiganga
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | aleksandrovskiy zavod
# Processing Record 32 of Set 3 | praia da vitoria
# Processing Record 33 of Set 3 | chernyshevskiy
# Processing Record 34 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 35 of Set 3 | trinidad
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | aksu
# Processing Record 38 of Set 3 | stornoway
# Processing Record 39 of Set 3 | port macquarie
# Processing Record 40 of Set 3 | oranjemund
# Processing Record 41 of Set 3 | terrace
# Processing Record 42 of Set 3 | zhezkazgan
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | atuona
# Processing Record 45 of Set 3 | tacuarembo
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | maryville
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 3 | gondar
# Processing Record 1 of Set 4 | tomatlan
# Processing Record 2 of Set 4 | rapid valley
# Processing Record 3 of Set 4 | camacha
# Processing Record 4 of Set 4 | butaritari
# Processing Record 5 of Set 4 | carthage
# Processing Record 6 of Set 4 | morada nova
# Processing Record 7 of Set 4 | baiyin
# Processing Record 8 of Set 4 | la ronge
# Processing Record 9 of Set 4 | barrow
# Processing Record 10 of Set 4 | ostrovnoy
# Processing Record 11 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 4 | playas
# Processing Record 13 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 4 | sheridan
# Processing Record 15 of Set 4 | sola
# Processing Record 16 of Set 4 | vila franca do campo
# Processing Record 17 of Set 4 | broome
# Processing Record 18 of Set 4 | ballina
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | havre-saint-pierre
# Processing Record 21 of Set 4 | bridlington
# Processing Record 22 of Set 4 | flin flon
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | juneau
# Processing Record 25 of Set 4 | georgetown
# Processing Record 26 of Set 4 | kuna
# Processing Record 27 of Set 4 | marfino
# Processing Record 28 of Set 4 | uusikaupunki
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | mocuba
# Processing Record 32 of Set 4 | the valley
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | banda aceh
# Processing Record 35 of Set 4 | namibe
# Processing Record 36 of Set 4 | kangaatsiaq
# Processing Record 37 of Set 4 | liniere
# City not found. Skipping...
# Processing Record 38 of Set 4 | jalu
# Processing Record 39 of Set 4 | nantucket
# Processing Record 40 of Set 4 | parrita
# Processing Record 41 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 4 | honiara
# Processing Record 43 of Set 4 | clyde river
# Processing Record 44 of Set 4 | bull savanna
# Processing Record 45 of Set 4 | opunake
# Processing Record 46 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 4 | waipawa
# Processing Record 48 of Set 4 | san cristobal
# Processing Record 49 of Set 4 | dandong
# Processing Record 50 of Set 4 | cockburn town
# Processing Record 1 of Set 5 | balabac
# Processing Record 2 of Set 5 | poum
# Processing Record 3 of Set 5 | kaniama
# Processing Record 4 of Set 5 | marsh harbour
# Processing Record 5 of Set 5 | bowen
# Processing Record 6 of Set 5 | port hardy
# Processing Record 7 of Set 5 | cabedelo
# Processing Record 8 of Set 5 | klaksvik
# Processing Record 9 of Set 5 | am timan
# Processing Record 10 of Set 5 | prince george
# Processing Record 11 of Set 5 | makakilo city
# Processing Record 12 of Set 5 | balykshi
# Processing Record 13 of Set 5 | grindavik
# Processing Record 14 of Set 5 | shiyan
# Processing Record 15 of Set 5 | mount gambier
# Processing Record 16 of Set 5 | narasapur
# Processing Record 17 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | lloydminster
# Processing Record 19 of Set 5 | bonavista
# Processing Record 20 of Set 5 | fare
# Processing Record 21 of Set 5 | mweka
# Processing Record 22 of Set 5 | baykit
# Processing Record 23 of Set 5 | iralaya
# Processing Record 24 of Set 5 | alekseyevsk
# Processing Record 25 of Set 5 | vladyslavivka
# Processing Record 26 of Set 5 | touros
# Processing Record 27 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 29 of Set 5 | avera
# Processing Record 30 of Set 5 | beloha
# Processing Record 31 of Set 5 | lagoa
# Processing Record 32 of Set 5 | arcachon
# Processing Record 33 of Set 5 | ribeira grande
# Processing Record 34 of Set 5 | chifeng
# Processing Record 35 of Set 5 | grand gaube
# Processing Record 36 of Set 5 | laguna
# Processing Record 37 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 5 | damphu
# Processing Record 39 of Set 5 | paamiut
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | dubti
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | port said
# Processing Record 44 of Set 5 | camana
# Processing Record 45 of Set 5 | havelock
# Processing Record 46 of Set 5 | skala fourkas
# Processing Record 47 of Set 5 | gushikawa
# Processing Record 48 of Set 5 | aswan
# Processing Record 49 of Set 5 | margate
# Processing Record 50 of Set 5 | madison
# Processing Record 1 of Set 6 | dikson
# Processing Record 2 of Set 6 | acapulco
# Processing Record 3 of Set 6 | faanui
# Processing Record 4 of Set 6 | mariental
# Processing Record 5 of Set 6 | mikuni
# Processing Record 6 of Set 6 | cairns
# Processing Record 7 of Set 6 | tambovka
# Processing Record 8 of Set 6 | taganak
# Processing Record 9 of Set 6 | pisco
# Processing Record 10 of Set 6 | labrea
# Processing Record 11 of Set 6 | alekseyevka
# Processing Record 12 of Set 6 | amboasary
# Processing Record 13 of Set 6 | torbay
# Processing Record 14 of Set 6 | hualmay
# Processing Record 15 of Set 6 | laukaa
# Processing Record 16 of Set 6 | novikovo
# Processing Record 17 of Set 6 | saint george
# Processing Record 18 of Set 6 | khonsa
# Processing Record 19 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 6 | soe
# Processing Record 21 of Set 6 | ondangwa
# Processing Record 22 of Set 6 | chapais
# Processing Record 23 of Set 6 | hay river
# Processing Record 24 of Set 6 | deputatskiy
# Processing Record 25 of Set 6 | puerto maldonado
# Processing Record 26 of Set 6 | srednekolymsk
# Processing Record 27 of Set 6 | nikolskoye
# Processing Record 28 of Set 6 | lompoc
# Processing Record 29 of Set 6 | kutum
# Processing Record 30 of Set 6 | matara
# Processing Record 31 of Set 6 | lufilufi
# Processing Record 32 of Set 6 | chekhov
# Processing Record 33 of Set 6 | westport
# Processing Record 34 of Set 6 | angoram
# Processing Record 35 of Set 6 | ilulissat
# Processing Record 36 of Set 6 | sambava
# Processing Record 37 of Set 6 | gigmoto
# Processing Record 38 of Set 6 | sangar
# Processing Record 39 of Set 6 | jumla
# Processing Record 40 of Set 6 | kasangulu
# Processing Record 41 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 42 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 43 of Set 6 | oskemen
# Processing Record 44 of Set 6 | isangel
# Processing Record 45 of Set 6 | hofn
# Processing Record 46 of Set 6 | bairnsdale
# Processing Record 47 of Set 6 | gamba
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | henties bay
# Processing Record 50 of Set 6 | bloemfontein
# Processing Record 1 of Set 7 | thunder bay
# Processing Record 2 of Set 7 | adwa
# Processing Record 3 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 7 | gat
# Processing Record 5 of Set 7 | abu zabad
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | codrington
# Processing Record 8 of Set 7 | srivardhan
# Processing Record 9 of Set 7 | nadvoitsy
# Processing Record 10 of Set 7 | alice springs
# Processing Record 11 of Set 7 | belaya gora
# Processing Record 12 of Set 7 | acu
# Processing Record 13 of Set 7 | nizhniy tsasuchey
# Processing Record 14 of Set 7 | buala
# Processing Record 15 of Set 7 | vasilkovo
# City not found. Skipping...
# Processing Record 16 of Set 7 | guane
# Processing Record 17 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 7 | songjianghe
# Processing Record 19 of Set 7 | andros town
# Processing Record 20 of Set 7 | adrar
# Processing Record 21 of Set 7 | hudson bay
# Processing Record 22 of Set 7 | the pas
# Processing Record 23 of Set 7 | yamada
# Processing Record 24 of Set 7 | vilhena
# Processing Record 25 of Set 7 | yushu
# Processing Record 26 of Set 7 | miraflores
# Processing Record 27 of Set 7 | binga
# Processing Record 28 of Set 7 | russell
# Processing Record 29 of Set 7 | sisimiut
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 7 | ust-ordynskiy
# Processing Record 33 of Set 7 | cabo san lucas
# Processing Record 34 of Set 7 | bundaberg
# Processing Record 35 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 7 | vestmannaeyjar
# Processing Record 37 of Set 7 | vao
# Processing Record 38 of Set 7 | mount isa
# Processing Record 39 of Set 7 | farah
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | tianpeng
# Processing Record 42 of Set 7 | uchiza
# Processing Record 43 of Set 7 | bulgan
# Processing Record 44 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 7 | marawi
# Processing Record 46 of Set 7 | mayo
# Processing Record 47 of Set 7 | himora
# City not found. Skipping...
# Processing Record 48 of Set 7 | vanavara
# Processing Record 49 of Set 7 | berkak
# Processing Record 50 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 8 | miracatu
# Processing Record 2 of Set 8 | machali
# Processing Record 3 of Set 8 | biak
# Processing Record 4 of Set 8 | hami
# Processing Record 5 of Set 8 | yulara
# Processing Record 6 of Set 8 | dubove
# Processing Record 7 of Set 8 | zhigansk
# Processing Record 8 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 8 | lipin bor
# Processing Record 10 of Set 8 | bontang
# Processing Record 11 of Set 8 | kurkino
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | ancud
# Processing Record 14 of Set 8 | xuddur
# Processing Record 15 of Set 8 | blagoyevo
# Processing Record 16 of Set 8 | asfi
# Processing Record 17 of Set 8 | olden
# Processing Record 18 of Set 8 | kiama
# Processing Record 19 of Set 8 | fairbanks
# Processing Record 20 of Set 8 | muros
# Processing Record 21 of Set 8 | kashi
# Processing Record 22 of Set 8 | innisfail
# Processing Record 23 of Set 8 | aquiraz
# Processing Record 24 of Set 8 | dingle
# Processing Record 25 of Set 8 | nemuro
# Processing Record 26 of Set 8 | jodhpur
# Processing Record 27 of Set 8 | kaabong
# Processing Record 28 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 8 | port lincoln
# Processing Record 30 of Set 8 | washington
# Processing Record 31 of Set 8 | necochea
# Processing Record 32 of Set 8 | tiznit
# Processing Record 33 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 8 | chulym
# Processing Record 35 of Set 8 | lebu
# Processing Record 36 of Set 8 | misratah
# Processing Record 37 of Set 8 | hirado
# Processing Record 38 of Set 8 | great yarmouth
# Processing Record 39 of Set 8 | dullewala
# Processing Record 40 of Set 8 | fulton
# Processing Record 41 of Set 8 | corinto
# Processing Record 42 of Set 8 | yumen
# Processing Record 43 of Set 8 | santa lucia
# Processing Record 44 of Set 8 | vostok
# Processing Record 45 of Set 8 | bushenyi
# Processing Record 46 of Set 8 | sampit
# Processing Record 47 of Set 8 | tautira
# Processing Record 48 of Set 8 | barcelona
# Processing Record 49 of Set 8 | hithadhoo
# Processing Record 50 of Set 8 | mehamn
# Processing Record 1 of Set 9 | hamilton
# Processing Record 2 of Set 9 | kalmunai
# Processing Record 3 of Set 9 | maldonado
# Processing Record 4 of Set 9 | jalingo
# Processing Record 5 of Set 9 | stawell
# Processing Record 6 of Set 9 | isilkul
# Processing Record 7 of Set 9 | hovd
# Processing Record 8 of Set 9 | pangkalanbuun
# Processing Record 9 of Set 9 | palmer
# Processing Record 10 of Set 9 | mangrol
# Processing Record 11 of Set 9 | miramar
# Processing Record 12 of Set 9 | jinxiang
# Processing Record 13 of Set 9 | vaitape
# Processing Record 14 of Set 9 | domingos martins
# Processing Record 15 of Set 9 | nacala
# Processing Record 16 of Set 9 | asilah
# Processing Record 17 of Set 9 | stephenville
# Processing Record 18 of Set 9 | caravelas
# Processing Record 19 of Set 9 | sorland
# Processing Record 20 of Set 9 | belmonte
# Processing Record 21 of Set 9 | pitimbu
# Processing Record 22 of Set 9 | lerwick
# Processing Record 23 of Set 9 | karratha
# Processing Record 24 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 9 | tocopilla
# Processing Record 26 of Set 9 | honningsvag
# Processing Record 27 of Set 9 | pokhara
# Processing Record 28 of Set 9 | akdagmadeni
# Processing Record 29 of Set 9 | muroto
# Processing Record 30 of Set 9 | tadine
# Processing Record 31 of Set 9 | lenger
# Processing Record 32 of Set 9 | emerald
# Processing Record 33 of Set 9 | suntar
# Processing Record 34 of Set 9 | jardim
# Processing Record 35 of Set 9 | alta gracia
# Processing Record 36 of Set 9 | nouadhibou
# Processing Record 37 of Set 9 | chumikan
# Processing Record 38 of Set 9 | aldan
# Processing Record 39 of Set 9 | price
# Processing Record 40 of Set 9 | mecca
# Processing Record 41 of Set 9 | iberia
# Processing Record 42 of Set 9 | davila
# Processing Record 43 of Set 9 | saint-pierre
# Processing Record 44 of Set 9 | shubarshi
# Processing Record 45 of Set 9 | namatanai
# Processing Record 46 of Set 9 | xihe
# Processing Record 47 of Set 9 | cartagena
# Processing Record 48 of Set 9 | ixtapa
# Processing Record 49 of Set 9 | tecpan
# Processing Record 50 of Set 9 | san quintin
# Processing Record 1 of Set 10 | ratnagiri
# Processing Record 2 of Set 10 | diego de almagro
# Processing Record 3 of Set 10 | okhotsk
# Processing Record 4 of Set 10 | dunedin
# Processing Record 5 of Set 10 | turmalina
# Processing Record 6 of Set 10 | zhob
# Processing Record 7 of Set 10 | elban
# Processing Record 8 of Set 10 | zyryanka
# Processing Record 9 of Set 10 | tulum
# Processing Record 10 of Set 10 | statesville
# Processing Record 11 of Set 10 | mayna
# Processing Record 12 of Set 10 | alugan
# Processing Record 13 of Set 10 | tsiroanomandidy
# Processing Record 14 of Set 10 | nova aurora
# Processing Record 15 of Set 10 | college
# Processing Record 16 of Set 10 | coquimbo
# Processing Record 17 of Set 10 | samarinda
# Processing Record 18 of Set 10 | san rafael del sur
# Processing Record 19 of Set 10 | los andes
# Processing Record 20 of Set 10 | sur
# Processing Record 21 of Set 10 | shelburne
# Processing Record 22 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 23 of Set 10 | basco
# Processing Record 24 of Set 10 | mayor pablo lagerenza
# Processing Record 25 of Set 10 | xiaoshi
# Processing Record 26 of Set 10 | moram
# Processing Record 27 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 10 | dryden
# Processing Record 29 of Set 10 | cap malheureux
# Processing Record 30 of Set 10 | walvis bay
# Processing Record 31 of Set 10 | sept-iles
# Processing Record 32 of Set 10 | provideniya
# Processing Record 33 of Set 10 | ridgecrest
# Processing Record 34 of Set 10 | galle
# Processing Record 35 of Set 10 | tabou
# Processing Record 36 of Set 10 | obo
# Processing Record 37 of Set 10 | tiksi
# Processing Record 38 of Set 10 | pafos
# Processing Record 39 of Set 10 | paka
# Processing Record 40 of Set 10 | sokolka
# Processing Record 41 of Set 10 | xam nua
# Processing Record 42 of Set 10 | aljustrel
# Processing Record 43 of Set 10 | aleppo
# Processing Record 44 of Set 10 | beisfjord
# Processing Record 45 of Set 10 | lindlar
# Processing Record 46 of Set 10 | ossora
# Processing Record 47 of Set 10 | emba
# Processing Record 48 of Set 10 | victoria
# Processing Record 49 of Set 10 | da nang
# Processing Record 50 of Set 10 | kvitok
# Processing Record 1 of Set 11 | turayf
# Processing Record 2 of Set 11 | broken hill
# Processing Record 3 of Set 11 | soyo
# Processing Record 4 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 5 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 11 | boldumsaz
# Processing Record 7 of Set 11 | sabha
# Processing Record 8 of Set 11 | rocha
# Processing Record 9 of Set 11 | botro
# Processing Record 10 of Set 11 | polunochnoye
# Processing Record 11 of Set 11 | fortuna
# Processing Record 12 of Set 11 | kadayanallur
# Processing Record 13 of Set 11 | jinchang
# Processing Record 14 of Set 11 | aurangabad
# Processing Record 15 of Set 11 | albina
# Processing Record 16 of Set 11 | fez
# Processing Record 17 of Set 11 | ambunti
# Processing Record 18 of Set 11 | berlevag
# Processing Record 19 of Set 11 | barguzin
# Processing Record 20 of Set 11 | wajima
# Processing Record 21 of Set 11 | port blair
# Processing Record 22 of Set 11 | twentynine palms
# Processing Record 23 of Set 11 | shakawe
# Processing Record 24 of Set 11 | port-gentil
# Processing Record 25 of Set 11 | halifax
# Processing Record 26 of Set 11 | djougou
# Processing Record 27 of Set 11 | salto
# Processing Record 28 of Set 11 | saldanha
# Processing Record 29 of Set 11 | molokovo
# Processing Record 30 of Set 11 | asau
# Processing Record 31 of Set 11 | nelson bay
# Processing Record 32 of Set 11 | fereydun kenar
# Processing Record 33 of Set 11 | haines junction
# Processing Record 34 of Set 11 | nguruka
# Processing Record 35 of Set 11 | yarada
# Processing Record 36 of Set 11 | salalah
# Processing Record 37 of Set 11 | suffolk
# Processing Record 38 of Set 11 | navolato
# Processing Record 39 of Set 11 | dunda
# Processing Record 40 of Set 11 | lasa
# Processing Record 41 of Set 11 | thinadhoo
# Processing Record 42 of Set 11 | itarema
# Processing Record 43 of Set 11 | sobolevo
# Processing Record 44 of Set 11 | serenje
# Processing Record 45 of Set 11 | novobirilyussy
# Processing Record 46 of Set 11 | maningrida
# Processing Record 47 of Set 11 | oranjestad
# Processing Record 48 of Set 11 | luganville
# Processing Record 49 of Set 11 | rock sound
# Processing Record 50 of Set 11 | kidal
# Processing Record 1 of Set 12 | rio gallegos
# Processing Record 2 of Set 12 | weligama
# Processing Record 3 of Set 12 | kulunda
# Processing Record 4 of Set 12 | flinders
# Processing Record 5 of Set 12 | half moon bay
# Processing Record 6 of Set 12 | panguipulli
# Processing Record 7 of Set 12 | grand forks
# Processing Record 8 of Set 12 | aksay
# Processing Record 9 of Set 12 | moron
# Processing Record 10 of Set 12 | fuerte olimpo
# Processing Record 11 of Set 12 | sucre
# Processing Record 12 of Set 12 | kieta
# Processing Record 13 of Set 12 | guaruja
# Processing Record 14 of Set 12 | pauini
# Processing Record 15 of Set 12 | rondonopolis
# Processing Record 16 of Set 12 | almaznyy
# Processing Record 17 of Set 12 | maluso
# Processing Record 18 of Set 12 | maceio
# Processing Record 19 of Set 12 | marsa matruh
# Processing Record 20 of Set 12 | azul
# Processing Record 21 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 12 | mitzic
# Processing Record 23 of Set 12 | puerto madryn
# Processing Record 24 of Set 12 | ocara
# Processing Record 25 of Set 12 | namie
# Processing Record 26 of Set 12 | bambanglipuro
# Processing Record 27 of Set 12 | kenora
# Processing Record 28 of Set 12 | roma
# Processing Record 29 of Set 12 | kholtoson
# Processing Record 30 of Set 12 | arman
# Processing Record 31 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 12 | evensk
# Processing Record 33 of Set 12 | valjala
# City not found. Skipping...
# Processing Record 34 of Set 12 | sandwick
# Processing Record 35 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 12 | pombia
# Processing Record 37 of Set 12 | port-cartier
# Processing Record 38 of Set 12 | richland
# Processing Record 39 of Set 12 | komsomolskiy
# Processing Record 40 of Set 12 | aguimes
# Processing Record 41 of Set 12 | khilok
# Processing Record 42 of Set 12 | la libertad
# Processing Record 43 of Set 12 | puerto escondido
# Processing Record 44 of Set 12 | snyder
# Processing Record 45 of Set 12 | pinhao
# Processing Record 46 of Set 12 | koumac
# Processing Record 47 of Set 12 | kununurra
# Processing Record 48 of Set 12 | sarangani
# Processing Record 49 of Set 12 | rabo de peixe
# Processing Record 50 of Set 12 | severobaykalsk
# Processing Record 1 of Set 13 | mersin
# Processing Record 2 of Set 13 | bangassou
# Processing Record 3 of Set 13 | te anau
# Processing Record 4 of Set 13 | kathmandu
# Processing Record 5 of Set 13 | shenjiamen
# Processing Record 6 of Set 13 | santiago del estero
# Processing Record 7 of Set 13 | tak bai
# Processing Record 8 of Set 13 | mission
# Processing Record 9 of Set 13 | usinsk
# Processing Record 10 of Set 13 | abrau-dyurso
# Processing Record 11 of Set 13 | tura
# Processing Record 12 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 13 of Set 13 | shimanovsk
# Processing Record 14 of Set 13 | coihaique
# Processing Record 15 of Set 13 | turukhansk
# Processing Record 16 of Set 13 | dalupirip
# Processing Record 17 of Set 13 | hambantota
# Processing Record 18 of Set 13 | male
# Processing Record 19 of Set 13 | alushta
# Processing Record 20 of Set 13 | neiafu
# Processing Record 21 of Set 13 | darhan
# Processing Record 22 of Set 13 | toccoa
# Processing Record 23 of Set 13 | sinnamary
# Processing Record 24 of Set 13 | talara
# Processing Record 25 of Set 13 | brae
# Processing Record 26 of Set 13 | saint-joseph
# Processing Record 27 of Set 13 | malibu
# Processing Record 28 of Set 13 | conakry
# Processing Record 29 of Set 13 | outlook
# Processing Record 30 of Set 13 | beroroha
# Processing Record 31 of Set 13 | erzin
# Processing Record 32 of Set 13 | martapura
# Processing Record 33 of Set 13 | biu
# Processing Record 34 of Set 13 | korem
# Processing Record 35 of Set 13 | miranda de ebro
# Processing Record 36 of Set 13 | kintampo
# Processing Record 37 of Set 13 | kupang
# Processing Record 38 of Set 13 | at-bashi
# Processing Record 39 of Set 13 | srandakan
# Processing Record 40 of Set 13 | morrope
# Processing Record 41 of Set 13 | lakeland highlands
# Processing Record 42 of Set 13 | udachnyy
# Processing Record 43 of Set 13 | nhulunbuy
# Processing Record 44 of Set 13 | christchurch
# Processing Record 45 of Set 13 | peniche
# Processing Record 46 of Set 13 | moerai
# Processing Record 47 of Set 13 | quatre cocos
# Processing Record 48 of Set 13 | kango
# Processing Record 49 of Set 13 | micheweni
# Processing Record 50 of Set 13 | faya
# Processing Record 1 of Set 14 | mataram
# Processing Record 2 of Set 14 | tzucacab
# Processing Record 3 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 14 | khandyga
# Processing Record 5 of Set 14 | tateyama
# Processing Record 6 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 7 of Set 14 | ust-tsilma
# Processing Record 8 of Set 14 | patancheru
# Processing Record 9 of Set 14 | kansanshi
# Processing Record 10 of Set 14 | santa rosa
# Processing Record 11 of Set 14 | bud
# Processing Record 12 of Set 14 | alta floresta
# Processing Record 13 of Set 14 | grand-santi
# Processing Record 14 of Set 14 | riosucio
# Processing Record 15 of Set 14 | tignere
# Processing Record 16 of Set 14 | sterling
# Processing Record 17 of Set 14 | doha
# Processing Record 18 of Set 14 | chunskiy
# Processing Record 19 of Set 14 | aksarka
# Processing Record 20 of Set 14 | koson
# Processing Record 21 of Set 14 | uyuni
# Processing Record 22 of Set 14 | inhambane
# Processing Record 23 of Set 14 | pekan
# Processing Record 24 of Set 14 | kitgum
# Processing Record 25 of Set 14 | myslenice
# Processing Record 26 of Set 14 | tsabong
# Processing Record 27 of Set 14 | santa engracia
# Processing Record 28 of Set 14 | homer
# Processing Record 29 of Set 14 | san vicente
# Processing Record 30 of Set 14 | nishihara
# Processing Record 31 of Set 14 | chimore
# Processing Record 32 of Set 14 | cauquenes
# Processing Record 33 of Set 14 | baishishan
# Processing Record 34 of Set 14 | myski
# Processing Record 35 of Set 14 | ngunguru
# Processing Record 36 of Set 14 | hangzhou
# Processing Record 37 of Set 14 | kaifeng
# Processing Record 38 of Set 14 | senj
# Processing Record 39 of Set 14 | santa cruz de tenerife
# Processing Record 40 of Set 14 | porto seguro
# Processing Record 41 of Set 14 | taksimo
# Processing Record 42 of Set 14 | xiongshi
# City not found. Skipping...
# Processing Record 43 of Set 14 | sechura
# Processing Record 44 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 14 | vitorino freire
# Processing Record 46 of Set 14 | hervey bay
# Processing Record 47 of Set 14 | zaysan
# Processing Record 48 of Set 14 | dhidhdhoo
# Processing Record 49 of Set 14 | buraydah
# Processing Record 50 of Set 14 | paternion
# Processing Record 1 of Set 15 | lokken verk
# City not found. Skipping...
# Processing Record 2 of Set 15 | xinzhi
# Processing Record 3 of Set 15 | san
# Processing Record 4 of Set 15 | manicore
# Processing Record 5 of Set 15 | skibbereen
# Processing Record 6 of Set 15 | saurimo
# Processing Record 7 of Set 15 | bubaque
# Processing Record 8 of Set 15 | lavrentiya
# Processing Record 9 of Set 15 | tilichiki
# Processing Record 10 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 15 | tarakan
# Processing Record 12 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 15 | jogbani
# Processing Record 14 of Set 15 | kyzyl-mazhalyk
# Processing Record 15 of Set 15 | destin
# Processing Record 16 of Set 15 | mezhevoy
# Processing Record 17 of Set 15 | dolinsk
# Processing Record 18 of Set 15 | inuvik
# Processing Record 19 of Set 15 | ambulu
# Processing Record 20 of Set 15 | chaa-khol
# City not found. Skipping...
# Processing Record 21 of Set 15 | poronaysk
# Processing Record 22 of Set 15 | gao
# Processing Record 23 of Set 15 | castres
# Processing Record 24 of Set 15 | sekoma
# Processing Record 25 of Set 15 | vestmanna
# Processing Record 26 of Set 15 | imperia
# Processing Record 27 of Set 15 | parnaiba
# Processing Record 28 of Set 15 | verkhnyaya toyma
# Processing Record 29 of Set 15 | bandipur
# Processing Record 30 of Set 15 | gainesville
# Processing Record 31 of Set 15 | sao jose da coroa grande
# Processing Record 32 of Set 15 | wum
# Processing Record 33 of Set 15 | tambacounda
# Processing Record 34 of Set 15 | goderich
# Processing Record 35 of Set 15 | humaita
# Processing Record 36 of Set 15 | ahuimanu
# Processing Record 37 of Set 15 | fort nelson
# Processing Record 38 of Set 15 | kawalu
# Processing Record 39 of Set 15 | krasnoselkup
# Processing Record 40 of Set 15 | bogomila
# Processing Record 41 of Set 15 | los algarrobos
# Processing Record 42 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 15 | santa vitoria do palmar
# Processing Record 44 of Set 15 | kiunga
# Processing Record 45 of Set 15 | awjilah
# Processing Record 46 of Set 15 | karaton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
cities_data_df=pd.DataFrame(city_data)
cities_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Airai      TL  -8.9266  125.4092     56.61        42          24
# 1        Kodiak      US  57.7900 -152.4072     50.67        98         100
# 2     Balutakay      PH   6.7211  125.3517     77.74        88          77
# 3  Puerto Ayora      EC  -0.7393  -90.3518     78.76        77          34
# 4        Bethel      US  41.3712  -73.4140     81.90        55           0
# 5     Jamestown      US  42.0970  -79.2353     79.02        54          73
# 6        Amahai      ID  -3.3333  128.9167     76.35        88         100
# 7   East London      ZA -33.0153   27.9116     59.07        68           0
# 8       Rikitea      PF -23.1203 -134.9692     68.70        55           0
# 9      Luderitz      NA -26.6481   15.1594     66.99        31           4
#
#    Wind Speed Current description
# 0        3.04          few clouds
# 1        7.63     overcast clouds
# 2        8.84       broken clouds
# 3        8.99    scattered clouds
# 4        2.86           clear sky
# 5        8.01       broken clouds
# 6        3.09     overcast clouds
# 7       19.22           clear sky
# 8        2.98           clear sky
# 9        4.61           clear sky

# %%
 #Reorder the column order
    
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current description"]

# %%
cities_data_df=cities_data_df[new_column_order]
cities_data_df
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                      Airai      TL  -8.9266  125.4092     56.61        42
# 1                     Kodiak      US  57.7900 -152.4072     50.67        98
# 2                  Balutakay      PH   6.7211  125.3517     77.74        88
# 3               Puerto Ayora      EC  -0.7393  -90.3518     78.76        77
# 4                     Bethel      US  41.3712  -73.4140     81.90        55
# ..                       ...     ...      ...       ...       ...       ...
# 682           Los Algarrobos      PA   8.5000  -82.4333     86.45        74
# 683  Santa Vitoria Do Palmar      BR -33.5189  -53.3681     68.34        64
# 684                   Kiunga      PG  -6.1219  141.2906     72.19       100
# 685                  Awjilah      LY  29.1081   21.2869     94.42        17
# 686                  Karaton      ID  -6.3424  106.1045     78.96        92
#
#      Cloudiness  Wind Speed Current description
# 0            24        3.04          few clouds
# 1           100        7.63     overcast clouds
# 2            77        8.84       broken clouds
# 3            34        8.99    scattered clouds
# 4             0        2.86           clear sky
# ..          ...         ...                 ...
# 682          40        5.75    scattered clouds
# 683          55        2.06       broken clouds
# 684         100        2.75     overcast clouds
# 685           0       14.36           clear sky
# 686           3        0.92           clear sky
#
# [687 rows x 9 columns]

# %%
#Create the output file(CSV).
output_data_file="WeatherPy_Database.csv"
# Export the City_Data into a CSV.
cities_data_df.to_csv(output_data_file,index_label="City_ID")
